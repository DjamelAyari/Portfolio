# %% [markdown]
# # Résultats des différentes requêtes

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
q1 = pd.read_csv("./templates/p1_base_de_donnees_sql_immo/p1_resultat_query_1.csv")
q2 = pd.read_csv("./templates/p1_base_de_donnees_sql_immo/p1_resultat_query_2.csv")
q3 = pd.read_csv("./templates/p1_base_de_donnees_sql_immo/p1_resultat_query_3.csv")
q4 = pd.read_csv("./templates/p1_base_de_donnees_sql_immo/p1_resultat_query_4.csv")
q5 = pd.read_csv("./templates/p1_base_de_donnees_sql_immo/p1_resultat_query_5.csv")
q6 = pd.read_csv("./templates/p1_base_de_donnees_sql_immo/p1_resultat_query_6.csv")
q7 = pd.read_csv("./templates/p1_base_de_donnees_sql_immo/p1_resultat_query_7.csv")
q8 = pd.read_csv("./templates/p1_base_de_donnees_sql_immo/p1_resultat_query_8.csv")
q9 = pd.read_csv("./templates/p1_base_de_donnees_sql_immo/p1_resultat_query_9.csv")

# %% [markdown]
# ***

# %% [markdown]
# ## <font color = "blue">1. Nombre total d’appartements vendus au 1er semestre 2020.</font>

# %%
q1
# Out:
#     type_local  nbr_appartements
# 0  Appartement             22692

# %% [markdown]
# **Le nombre total d'appartement vendus au 1er semestre 2020 est de 22 692.**

# %% [markdown]
# ***

# %% [markdown]
# ## <font color = "red">2. Proportion des ventes d’appartements par le nombre de pièces.</font>

# %%
q2
# Out:
#     nombre_pieces_principales  COUNT  percent
# 0                           0     30    0.101
# 1                           1   5521   18.589
# 2                           2   8099   27.269
# 3                           3   7685   25.875
# 4                           4   4199   14.138
# 5                           5   1104    3.717
# 6                           6    204    0.687
# 7                           7     54    0.182
# 8                           8     17    0.057
# 9                           9      8    0.027
# 10                         10      2    0.007
# 11                         11      1    0.003

# %% [markdown]
# **L'on peut constater que les 2 et 3 pièces sont ceux qui représentent les plus grandes proportions.**
#
#     -2 --> 27.269 %
#     -3 --> 25.875 %
#
# **Ensuite il y a les 1 et 4 pièces.**
#
#     -1 --> 18.589 %
#     -4 --> 14.138 %
#
# **Pour les autres l'on ne dépasse pas les 4%.**

# %% [markdown]
# ***

# %% [markdown]
# ## <font color = "green">3. Liste des 10 départements où le prix du mètre carré est le plus élevé.</font>

# %%
q3
# Out:
#    departements  Prix_metre_carre
# 0           971      13739.694405
# 1            95      12341.982669
# 2           973      10156.573482
# 3            75       9835.979937
# 4           972       8294.955113
# 5           974       7267.855759
# 6            94       6879.843364
# 7            91       6825.708818
# 8            92       5090.810203
# 9             8       4880.152815

# %% [markdown]
# **Les départements où le prix du mètre carré est le plus élévé sont:**
#
#     971 --> Guadeloupe
#     95 --> Val-d'Oise (Île-de-France)
#     973 --> Guyane
#     75 --> Paris (Île-de-France)
#     972 --> Martinique
#     974 --> Réunion
#     94 --> Val-de-Marne (Île-de-France)
#     91 --> Essonne (Île-de-France)
#     92 --> Hauts-de-Seine (Île-de-France)
#     8 --> Ardennes
#
# **Donc les départements les plus chers au mètre carré sont situés majoritairement dans les DOM-TOM et en Île-de-France.**
#
# **Sans oublier le département des Ardennes qui se situent au Nord de la France.**

# %% [markdown]
# ***

# %% [markdown]
# ## <font color = "orange">4. Prix moyen du mètre carré d’une maison en Île-de-France.</font>

# %%
q4
# Out:
#    AVG(Prix_metre_carre)
# 0            4486.400993

# %% [markdown]
# **En Île-de-France le prix moyen au mètre carré est de 4 486.40 €.**

# %% [markdown]
# ***

# %% [markdown]
# ## <font color = "pink">5. Liste des 10 appartements les plus chers avec le département et le nombre de mètres carrés.</font>

# %%
q5
# Out:
#     type_local  valeur_fonciere  departements  surface_carrez
# 0  Appartement        8577713.0            95           77.05
# 1  Appartement        7620000.0            75          101.51
# 2  Appartement        7600000.0            95           62.78
# 3  Appartement        7535000.0            94           52.78
# 4  Appartement        7420000.0            75           60.08
# 5  Appartement        6600000.0            94           29.26
# 6  Appartement        6454000.0            94           66.08
# 7  Appartement        6000000.0            95           30.20
# 8  Appartement        5600000.0            94           37.24
# 9  Appartement        5500000.0            95           89.30

# %% [markdown]
# **Ici l'on peut voir sans grande surprise que la liste est entièrement composée d'appartements situés en Île-de-France.**
#
# **Les surfaces carrez vont de 29.26m² à 101.51m².**

# %% [markdown]
# ***

# %% [markdown]
# ## <font color = "purple">6. Taux d’évolution du nombre de ventes entre le premier et le second trimestre de 2020.</font>

# %%
q6
# Out:
#       T1     T2  evolution
# 0  14764  14220    -3.6846

# %% [markdown]
# **L'évolution des ventes entre le 1er et le 2nd trimestre est négative.**
#
# **Il y a une dévolution de 3.68.**

# %% [markdown]
# ***

# %% [markdown]
# ## <font color = "Ivory">7. Liste des communes où le nombre de ventes a augmenté d'au moins 20% entre le premier et le second trimestre de 2020.</font>

# %%
q7
# Out:
#                           commune  evolution
# 0                           ZONZA    28.5714
# 1                          YVETOT    66.6667
# 2                          YERRES    80.0000
# 3                   WITRYLESREIMS    28.5714
# 4                         WISSOUS    68.7500
# 5                          WAVRIN    28.5714
# 6                       WATTRELOS    28.5714
# 7                      WATTIGNIES    37.5000
# 8                       WASQUEHAL    37.5000
# 9                         VOREPPE    61.5385
# 10            VOISINSLEBRETONNEUX    50.0000
# 11                         VOIRON    54.5455
# 12                        VIZILLE    54.5455
# 13                   VIUZENSALLAZ    28.5714
# 14                  VITRYSURSEINE    84.8485
# 15              VITRY LE FRANCOIS    37.5000
# 16                 VIRY CHATILLON    78.2609
# 17                           VIRY    28.5714
# 18                       VIROFLAY    70.5882
# 19                      VINCENNES    91.9355
# ...

# %% [markdown]
# ***

# %% [markdown]
# ## <font color = "darkblue">8. Différence en pourcentage du prix au mètre carré entre un appartement de 2 pièces et un appartement de 3 pièces.</font>

# %%
q8
# Out:
#    Prix_metre_carre_T2  Prix_metre_carre_T3  resultat
# 0          4953.500225          4475.689417 -9.645923

# %% [markdown]
# **La différence est qu'un T3 est 9.65% moins cher qu'un T2.**

# %% [markdown]
# ***

# %% [markdown]
# ## <font color = "magenta">9. Les moyennes de valeurs foncières pour le top 3 des communes des départements 6, 13, 33, 59 et 69.</font>

# %%
q9.round(2)
# Out:
#         avg_vf  departements                 commune  ranking
# 0   1100000.00             6               LA BRIGUE        1
# 1    355000.00             6                   TENDE        2
# 2    247649.95             6               VALLAURIS        3
# 3    425000.00            13         ENSUESLAREDONNE        1
# 4    390000.00            13           CHATEAURENARD        2
# 5    267633.33            13                GREASQUE        3
# 6    561500.00            33  ST SULPICE ET CAMEYRAC        3
# 7    522500.00            33                  CESTAS        1
# 8    454728.75            33             BLANQUEFORT        2
# 9    504500.00            59      ENNETIERESENWEPPES        2
# 10   344500.00            59                  WAVRIN        1
# 11   156361.11            59               TOURCOING        3
# 12   515185.00            69   SAINTEFOYL ARGENTIERE        1
# 13   286209.17            69                 MEYZIEU        2
# ...
